# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# Load dataset
dataset = pd.read_csv('diabetes.csv')
# Split dataset into features (X) and target variable (Y)
X = dataset.iloc[:, :-1]  # Features are all columns except the last one
Y = dataset.iloc[:, -1]   # Target variable is the last column

# Split dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Define the model
np.random.seed(155)
my_first_nn = Sequential()
# Add dense layers
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 1
my_first_nn.add(Dense(15, activation='relu')) # hidden layer 2
# Additional dense layer
my_first_nn.add(Dense(10, activation='relu')) # hidden layer 3

# Output layer
my_first_nn.add(Dense(1, activation='sigmoid'))
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)
print(my_first_nn.summary())
evaluation_result = my_first_nn.evaluate(X_test, Y_test)
print("Accuracy : ", evaluation_result[1]*100)
# Out:
# WARNING:tensorflow:From C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 18/18 [==============================] - 2s 4ms/step - loss: 5.3252 - accuracy: 0.4504
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0025 - accuracy: 0.6261
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8718 - accuracy: 0.6330
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7760 - accuracy: 0.6104
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.6052
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.6070
# Epoch 7/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.6070
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6716 - accuracy: 0.6400
# Epoch 9/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6621 - accuracy: 0.6470
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6583 - accuracy: 0.6539
# Epoch 11/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6533 - accuracy: 0.6591
# Epoch 12/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6504 - accuracy: 0.6574
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6504 - accuracy: 0.6574
# Epoch 14/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6499 - accuracy: 0.6557
# Epoch 15/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6447 - accuracy: 0.6661
# Epoch 16/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6451 - accuracy: 0.6643
# Epoch 17/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6433 - accuracy: 0.6643
# Epoch 18/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6431 - accuracy: 0.6678
# Epoch 19/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6407 - accuracy: 0.6626
# Epoch 20/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6393 - accuracy: 0.6661
# Epoch 21/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6376 - accuracy: 0.6678
# Epoch 22/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6402 - accuracy: 0.6643
# Epoch 23/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6386 - accuracy: 0.6678
# Epoch 24/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6730
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6347 - accuracy: 0.6678
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6338 - accuracy: 0.6626
# Epoch 27/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6336 - accuracy: 0.6696
# Epoch 28/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6696
# Epoch 29/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.6678
# Epoch 30/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6296 - accuracy: 0.6678
# Epoch 31/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6273 - accuracy: 0.6696
# Epoch 32/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6265 - accuracy: 0.6713
# Epoch 33/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6247 - accuracy: 0.6696
# Epoch 34/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6276 - accuracy: 0.6661
# Epoch 35/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6228 - accuracy: 0.6713
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.6696
# Epoch 37/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6300 - accuracy: 0.6661
# Epoch 38/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.6678
# Epoch 39/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.6214 - accuracy: 0.6678
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6210 - accuracy: 0.6661
# Epoch 41/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6186 - accuracy: 0.6643
# Epoch 42/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6199 - accuracy: 0.6643
# Epoch 43/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6170 - accuracy: 0.6643
# Epoch 44/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6146 - accuracy: 0.6678
# Epoch 45/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6124 - accuracy: 0.6696
# Epoch 46/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.6696
# Epoch 47/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6120 - accuracy: 0.6748
# Epoch 48/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.6696
# Epoch 49/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6104 - accuracy: 0.6713
# Epoch 50/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6111 - accuracy: 0.6661
# Epoch 51/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6063 - accuracy: 0.6696
# Epoch 52/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6033 - accuracy: 0.6696
# Epoch 53/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6032 - accuracy: 0.6730
# Epoch 54/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6016 - accuracy: 0.6696
# Epoch 55/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.6661
# Epoch 56/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6037 - accuracy: 0.6713
# Epoch 57/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.6730
# Epoch 58/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.6696
# Epoch 59/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5977 - accuracy: 0.6696
# Epoch 60/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5966 - accuracy: 0.6730
# Epoch 61/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5984 - accuracy: 0.6713
# Epoch 62/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5945 - accuracy: 0.6713
# Epoch 63/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5939 - accuracy: 0.6713
# Epoch 64/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5955 - accuracy: 0.6713
# Epoch 65/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.6730
# Epoch 66/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5963 - accuracy: 0.6713
# Epoch 67/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5973 - accuracy: 0.6661
# Epoch 68/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5896 - accuracy: 0.6730
# Epoch 69/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5881 - accuracy: 0.6730
# Epoch 70/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.6748
# Epoch 71/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5885 - accuracy: 0.6696
# Epoch 72/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.6696
# Epoch 73/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5861 - accuracy: 0.6730
# Epoch 74/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5830 - accuracy: 0.6765
# Epoch 75/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5839 - accuracy: 0.6713
# Epoch 76/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5823 - accuracy: 0.6748
# Epoch 77/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5820 - accuracy: 0.6765
# Epoch 78/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5812 - accuracy: 0.6748
# Epoch 79/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.6696
# Epoch 80/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5795 - accuracy: 0.6730
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5831 - accuracy: 0.6730
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5856 - accuracy: 0.6730
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.6765
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5779 - accuracy: 0.6765
# Epoch 85/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5775 - accuracy: 0.6765
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5763 - accuracy: 0.6783
# Epoch 87/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5774 - accuracy: 0.6748
# Epoch 88/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5791 - accuracy: 0.6730
# Epoch 89/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.6765
# Epoch 90/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.6713
# Epoch 91/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5764 - accuracy: 0.6748
# Epoch 92/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5750 - accuracy: 0.6748
# Epoch 93/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.6713
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.6783
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5741 - accuracy: 0.6783
# Epoch 96/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5759 - accuracy: 0.6783
# Epoch 97/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5750 - accuracy: 0.6730
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5852 - accuracy: 0.6678
# Epoch 99/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5745 - accuracy: 0.6748
# Epoch 100/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.6696
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 15)                315
#
#  dense_2 (Dense)             (None, 10)                160
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 666 (2.60 KB)
# Trainable params: 666 (2.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5790 - accuracy: 0.7031
# Accuracy :  70.3125

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Loading the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Splitting the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Normalizing the data using StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Training the model
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.2)

# Evaluating the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 2s 16ms/step - loss: 0.7077 - accuracy: 0.6429 - val_loss: 0.7151 - val_accuracy: 0.6044
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.5785 - accuracy: 0.6456 - val_loss: 0.5977 - val_accuracy: 0.6044
# Epoch 3/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.4875 - accuracy: 0.6429 - val_loss: 0.5139 - val_accuracy: 0.6044
# Epoch 4/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.4275 - accuracy: 0.6484 - val_loss: 0.4618 - val_accuracy: 0.6264
# Epoch 5/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.3896 - accuracy: 0.8242 - val_loss: 0.4238 - val_accuracy: 0.8462
# Epoch 6/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.3634 - accuracy: 0.8654 - val_loss: 0.3927 - val_accuracy: 0.9011
# Epoch 7/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.3375 - accuracy: 0.9121 - val_loss: 0.3536 - val_accuracy: 0.9780
# Epoch 8/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.3022 - accuracy: 0.9423 - val_loss: 0.2980 - val_accuracy: 0.9780
# Epoch 9/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2523 - accuracy: 0.9505 - val_loss: 0.2381 - val_accuracy: 0.9890
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9670 - val_loss: 0.1856 - val_accuracy: 1.0000
# Epoch 11/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.1668 - accuracy: 0.9753 - val_loss: 0.1500 - val_accuracy: 0.9890
# Epoch 12/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.9753 - val_loss: 0.1271 - val_accuracy: 0.9780
# Epoch 13/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.1224 - accuracy: 0.9780 - val_loss: 0.1108 - val_accuracy: 0.9780
# Epoch 14/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.1102 - accuracy: 0.9835 - val_loss: 0.0986 - val_accuracy: 0.9780
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.1010 - accuracy: 0.9808 - val_loss: 0.0898 - val_accuracy: 0.9890
# Epoch 16/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0938 - accuracy: 0.9835 - val_loss: 0.0835 - val_accuracy: 0.9890
# Epoch 17/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0881 - accuracy: 0.9808 - val_loss: 0.0786 - val_accuracy: 0.9890
# Epoch 18/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9835 - val_loss: 0.0739 - val_accuracy: 0.9890
# Epoch 19/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9808 - val_loss: 0.0699 - val_accuracy: 0.9890
# Epoch 20/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0770 - accuracy: 0.9863 - val_loss: 0.0668 - val_accuracy: 0.9890
# Epoch 21/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.9863 - val_loss: 0.0647 - val_accuracy: 0.9890
# Epoch 22/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0713 - accuracy: 0.9863 - val_loss: 0.0622 - val_accuracy: 0.9890
# Epoch 23/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9863 - val_loss: 0.0596 - val_accuracy: 0.9890
# Epoch 24/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0667 - accuracy: 0.9863 - val_loss: 0.0578 - val_accuracy: 0.9780
# Epoch 25/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9863 - val_loss: 0.0560 - val_accuracy: 0.9780
# Epoch 26/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0632 - accuracy: 0.9863 - val_loss: 0.0543 - val_accuracy: 0.9780
# Epoch 27/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9863 - val_loss: 0.0524 - val_accuracy: 0.9780
# Epoch 28/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0598 - accuracy: 0.9863 - val_loss: 0.0513 - val_accuracy: 0.9780
# Epoch 29/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0585 - accuracy: 0.9863 - val_loss: 0.0497 - val_accuracy: 0.9780
# Epoch 30/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9863 - val_loss: 0.0484 - val_accuracy: 0.9780
# Epoch 31/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0553 - accuracy: 0.9863 - val_loss: 0.0470 - val_accuracy: 0.9780
# Epoch 32/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0543 - accuracy: 0.9863 - val_loss: 0.0460 - val_accuracy: 0.9780
# Epoch 33/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0528 - accuracy: 0.9863 - val_loss: 0.0451 - val_accuracy: 0.9780
# Epoch 34/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9863 - val_loss: 0.0446 - val_accuracy: 0.9890
# Epoch 35/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0507 - accuracy: 0.9863 - val_loss: 0.0431 - val_accuracy: 0.9890
# Epoch 36/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9863 - val_loss: 0.0420 - val_accuracy: 0.9890
# Epoch 37/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0490 - accuracy: 0.9863 - val_loss: 0.0413 - val_accuracy: 0.9890
# Epoch 38/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0482 - accuracy: 0.9863 - val_loss: 0.0423 - val_accuracy: 0.9890
# Epoch 39/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0471 - accuracy: 0.9863 - val_loss: 0.0414 - val_accuracy: 0.9890
# Epoch 40/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 0.9863 - val_loss: 0.0399 - val_accuracy: 0.9890
# Epoch 41/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9863 - val_loss: 0.0391 - val_accuracy: 0.9890
# Epoch 42/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9863 - val_loss: 0.0378 - val_accuracy: 0.9890
# Epoch 43/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0442 - accuracy: 0.9863 - val_loss: 0.0365 - val_accuracy: 0.9890
# Epoch 44/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0432 - accuracy: 0.9863 - val_loss: 0.0364 - val_accuracy: 0.9890
# Epoch 45/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9890 - val_loss: 0.0352 - val_accuracy: 0.9890
# Epoch 46/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0419 - accuracy: 0.9890 - val_loss: 0.0355 - val_accuracy: 0.9890
# Epoch 47/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9890 - val_loss: 0.0340 - val_accuracy: 0.9890
# Epoch 48/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0405 - accuracy: 0.9890 - val_loss: 0.0334 - val_accuracy: 0.9890
# Epoch 49/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9918 - val_loss: 0.0334 - val_accuracy: 0.9890
# Epoch 50/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.9918 - val_loss: 0.0329 - val_accuracy: 0.9890
# Epoch 51/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0383 - accuracy: 0.9918 - val_loss: 0.0315 - val_accuracy: 0.9890
# Epoch 52/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 0.9918 - val_loss: 0.0310 - val_accuracy: 0.9890
# Epoch 53/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0370 - accuracy: 0.9918 - val_loss: 0.0307 - val_accuracy: 0.9890
# Epoch 54/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 0.9918 - val_loss: 0.0304 - val_accuracy: 0.9890
# Epoch 55/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0354 - accuracy: 0.9918 - val_loss: 0.0292 - val_accuracy: 0.9890
# Epoch 56/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0348 - accuracy: 0.9918 - val_loss: 0.0293 - val_accuracy: 0.9890
# Epoch 57/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9918 - val_loss: 0.0296 - val_accuracy: 0.9890
# Epoch 58/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9918 - val_loss: 0.0291 - val_accuracy: 0.9890
# Epoch 59/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0328 - accuracy: 0.9918 - val_loss: 0.0288 - val_accuracy: 0.9890
# Epoch 60/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9918 - val_loss: 0.0284 - val_accuracy: 0.9890
# Epoch 61/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9918 - val_loss: 0.0281 - val_accuracy: 0.9890
# Epoch 62/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9918 - val_loss: 0.0265 - val_accuracy: 0.9890
# Epoch 63/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9918 - val_loss: 0.0276 - val_accuracy: 0.9890
# Epoch 64/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9918 - val_loss: 0.0272 - val_accuracy: 0.9890
# Epoch 65/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 0.0264 - val_accuracy: 0.9890
# Epoch 66/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.0248 - val_accuracy: 0.9890
# Epoch 67/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9918 - val_loss: 0.0257 - val_accuracy: 0.9890
# Epoch 68/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.0248 - val_accuracy: 0.9890
# Epoch 69/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.0248 - val_accuracy: 0.9890
# Epoch 70/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9918 - val_loss: 0.0245 - val_accuracy: 0.9890
# Epoch 71/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0239 - val_accuracy: 0.9890
# Epoch 72/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9918 - val_loss: 0.0230 - val_accuracy: 0.9890
# Epoch 73/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.0236 - val_accuracy: 0.9890
# Epoch 74/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9918 - val_loss: 0.0225 - val_accuracy: 0.9890
# Epoch 75/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.0225 - val_accuracy: 0.9890
# Epoch 76/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9918 - val_loss: 0.0214 - val_accuracy: 0.9890
# Epoch 77/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0229 - accuracy: 0.9918 - val_loss: 0.0222 - val_accuracy: 0.9890
# Epoch 78/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9918 - val_loss: 0.0210 - val_accuracy: 0.9890
# Epoch 79/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9918 - val_loss: 0.0209 - val_accuracy: 0.9890
# Epoch 80/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.0217 - val_accuracy: 0.9890
# Epoch 81/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9945 - val_loss: 0.0214 - val_accuracy: 0.9890
# Epoch 82/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9945 - val_loss: 0.0206 - val_accuracy: 0.9890
# Epoch 83/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0209 - accuracy: 0.9945 - val_loss: 0.0208 - val_accuracy: 0.9890
# Epoch 84/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0202 - accuracy: 0.9918 - val_loss: 0.0206 - val_accuracy: 0.9890
# Epoch 85/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9945 - val_loss: 0.0201 - val_accuracy: 0.9890
# Epoch 86/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 0.9945 - val_loss: 0.0204 - val_accuracy: 0.9890
# Epoch 87/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.0197 - val_accuracy: 0.9890
# Epoch 88/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9945 - val_loss: 0.0201 - val_accuracy: 0.9890
# Epoch 89/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0196 - val_accuracy: 0.9890
# Epoch 90/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.0196 - val_accuracy: 0.9890
# Epoch 91/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9973 - val_loss: 0.0207 - val_accuracy: 0.9890
# Epoch 92/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9973 - val_loss: 0.0205 - val_accuracy: 0.9890
# Epoch 93/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9973 - val_loss: 0.0197 - val_accuracy: 0.9890
# Epoch 94/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 0.9973 - val_loss: 0.0195 - val_accuracy: 0.9890
# Epoch 95/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 0.9973 - val_loss: 0.0198 - val_accuracy: 0.9890
# Epoch 96/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 0.9973 - val_loss: 0.0195 - val_accuracy: 0.9890
# Epoch 97/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.0184 - val_accuracy: 0.9890
# Epoch 98/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9973 - val_loss: 0.0185 - val_accuracy: 0.9890
# Epoch 99/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9973 - val_loss: 0.0188 - val_accuracy: 0.9890
# Epoch 100/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9973 - val_loss: 0.0178 - val_accuracy: 0.9890
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1834 - accuracy: 0.9386
# Accuracy: 93.86

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer

# Load Breast Cancer dataset
data = load_breast_cancer()
X, Y = data.data, data.target

# Normalize the data
sc = StandardScaler()
X_normalized = sc.fit_transform(X)

# Split dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_normalized, Y, test_size=0.25, random_state=87)

# Define the model
np.random.seed(155)
my_first_nn = Sequential()

# Add dense layers
my_first_nn.add(Dense(20, input_dim=X_train.shape[1], activation='relu')) # hidden layer 1
my_first_nn.add(Dense(15, activation='relu')) # hidden layer 2
# Additional dense layer
my_first_nn.add(Dense(10, activation='relu')) # hidden layer 3

# Output layer
my_first_nn.add(Dense(1, activation='sigmoid'))
# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)
print(my_first_nn.summary())
# Evaluate the model on test data
evaluation_result = my_first_nn.evaluate(X_test, Y_test)
print("Accuracy : ", evaluation_result[1]*100)  # Print accuracy value
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 3ms/step - loss: 0.5999 - accuracy: 0.5587
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4417 - accuracy: 0.8474
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3323 - accuracy: 0.9038
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9272
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2032 - accuracy: 0.9296
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.9366
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9437
# Epoch 8/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9484
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1158 - accuracy: 0.9554
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.9554
# Epoch 11/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0975 - accuracy: 0.9577
# Epoch 12/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9671
# Epoch 13/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9695
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9718
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9718
# Epoch 16/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9742
# Epoch 17/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9765
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9812
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 0.9859
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 0.9859
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9906
# Epoch 22/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9906
# Epoch 23/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9930
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9930
# Epoch 25/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9930
# Epoch 26/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9930
# Epoch 27/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9930
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9930
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9930
# Epoch 31/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9930
# Epoch 32/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9930
# Epoch 33/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9953
# Epoch 34/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9953
# Epoch 35/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9953
# Epoch 36/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9953
# Epoch 37/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9953
# Epoch 38/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9953
# Epoch 39/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9953
# Epoch 40/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9953
# Epoch 41/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 43/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 44/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 46/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 49/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 50/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 52/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 53/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 54/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 57/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 59/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 62/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 63/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 64/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 65/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 66/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 67/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 71/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 72/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 73/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 76/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 77/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 79/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 80/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 81/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 82/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 83/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 84/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 85/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 86/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 90/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 91/100
# 14/14 [==============================] - 0s 4ms/step - loss: 9.8143e-04 - accuracy: 1.0000
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.4730e-04 - accuracy: 1.0000
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.6155e-04 - accuracy: 1.0000
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.7664e-04 - accuracy: 1.0000
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.4843e-04 - accuracy: 1.0000
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.4337e-04 - accuracy: 1.0000
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.1197e-04 - accuracy: 1.0000
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.7964e-04 - accuracy: 1.0000
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.5516e-04 - accuracy: 1.0000
# Epoch 100/100
# 14/14 [==============================] - 0s 4ms/step - loss: 7.3437e-04 - accuracy: 1.0000
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 20)                620
#
#  dense_8 (Dense)             (None, 15)                315
#
#  dense_9 (Dense)             (None, 10)                160
#
#  dense_10 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1106 (4.32 KB)
# Trainable params: 1106 (4.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.9720
# Accuracy :  97.20279574394226

# %%
#Given image classification source code

from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
model.save('mnist_model.h5')
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 5s 18ms/step - loss: 0.2896 - accuracy: 0.9126 - val_loss: 0.1295 - val_accuracy: 0.9613
# Epoch 2/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0991 - accuracy: 0.9696 - val_loss: 0.0901 - val_accuracy: 0.9729
# Epoch 3/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0625 - accuracy: 0.9804 - val_loss: 0.0911 - val_accuracy: 0.9721
# Epoch 4/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0421 - accuracy: 0.9864 - val_loss: 0.0840 - val_accuracy: 0.9752
# Epoch 5/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 0.0669 - val_accuracy: 0.9800
# Epoch 6/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0853 - val_accuracy: 0.9775
# Epoch 7/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0167 - accuracy: 0.9951 - val_loss: 0.0809 - val_accuracy: 0.9778
# Epoch 8/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0778 - val_accuracy: 0.9803
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0737 - val_accuracy: 0.9825
# Epoch 10/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0676 - val_accuracy: 0.9829
# C:\Users\gadda\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Task 1
import numpy as np
import matplotlib.pyplot as plt
from keras import Sequential
from keras.layers import Dense
from keras.datasets import mnist
from keras.utils import to_categorical
# Load dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Process the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float') / 255.0
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float') / 255.0
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)
# Define the model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Fit the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10,
                    verbose=1,validation_data=(test_data, test_labels_one_hot))

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 235/235 [==============================] - 5s 18ms/step - loss: 0.2866 - accuracy: 0.9129 - val_loss: 0.1249 - val_accuracy: 0.9612
# Epoch 2/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0994 - accuracy: 0.9695 - val_loss: 0.0898 - val_accuracy: 0.9716
# Epoch 3/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0632 - accuracy: 0.9801 - val_loss: 0.0893 - val_accuracy: 0.9721
# Epoch 4/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0425 - accuracy: 0.9869 - val_loss: 0.0654 - val_accuracy: 0.9777
# Epoch 5/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0313 - accuracy: 0.9896 - val_loss: 0.0810 - val_accuracy: 0.9756
# Epoch 6/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0870 - val_accuracy: 0.9733
# Epoch 7/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.0598 - val_accuracy: 0.9827
# Epoch 8/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0642 - val_accuracy: 0.9826
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0745 - val_accuracy: 0.9817
# Epoch 10/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0787 - val_accuracy: 0.9804

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras import Sequential
from keras.layers import Dense
from keras.datasets import mnist
from keras.utils import to_categorical

# Load dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Process the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float') / 255.0
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float') / 255.0
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Define the model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model
model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1)

# Plot one of the images in the test data
plt.imshow(test_images[0], cmap='gray')
plt.show()

# Make prediction on the single image
prediction = model.predict(test_data[0].reshape(1, 784))
print("Prediction:", np.argmax(prediction))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 5s 16ms/step - loss: 0.2907 - accuracy: 0.9124
# Epoch 2/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0999 - accuracy: 0.9697
# Epoch 3/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0635 - accuracy: 0.9801
# Epoch 4/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0445 - accuracy: 0.9859
# Epoch 5/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0318 - accuracy: 0.9896
# Epoch 6/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0222 - accuracy: 0.9929
# Epoch 7/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0172 - accuracy: 0.9946
# Epoch 8/10
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0123 - accuracy: 0.9961
# Epoch 9/10
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0098 - accuracy: 0.9970
# Epoch 10/10
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0082 - accuracy: 0.9974
# 1/1 [==============================] - 0s 174ms/step
# Prediction: 7

# %%
# Load the MNIST dataset
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam  # Import Adam optimizer separately

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Convert the pixel values to floats and normalize them to the range 0-1
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert the target variable to a one-hot encoding using to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create a neural network model with 3 hidden layers and tanh activation
model = Sequential()
model.add(Dense(256, input_dim=784, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(10, activation='softmax'))

# Compile the model using the Adam optimizer
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# Train the model
history = model.fit(x_train.reshape(-1, 784), y_train, epochs=10, validation_data=(x_test.reshape(-1, 784), y_test))

# Plot the loss and accuracy for both training and validation data
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2377 - accuracy: 0.9282 - val_loss: 0.1253 - val_accuracy: 0.9618
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1120 - accuracy: 0.9652 - val_loss: 0.1100 - val_accuracy: 0.9650
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0793 - accuracy: 0.9751 - val_loss: 0.1006 - val_accuracy: 0.9675
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0607 - accuracy: 0.9807 - val_loss: 0.0853 - val_accuracy: 0.9727
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0905 - val_accuracy: 0.9738
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0404 - accuracy: 0.9873 - val_loss: 0.0856 - val_accuracy: 0.9727
# Epoch 7/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.0726 - val_accuracy: 0.9762
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0302 - accuracy: 0.9901 - val_loss: 0.0728 - val_accuracy: 0.9776
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0272 - accuracy: 0.9906 - val_loss: 0.0826 - val_accuracy: 0.9767
# Epoch 10/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 0.0796 - val_accuracy: 0.9773

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0674, Test accuracy: 0.9809
# 1 hidden layer with sigmoid - Test loss: 0.0587, Test accuracy: 0.9827
# 2 hidden layers with tanh - Test loss: 0.0739, Test accuracy: 0.9799
# 2 hidden layers with sigmoid - Test loss: 0.0594, Test accuracy: 0.9843

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
train_images = train_images.reshape((train_images.shape[0], -1)).astype('float32') / 255.0
test_images = test_images.reshape((test_images.shape[0], -1)).astype('float32') / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Define a function to create and compile the model with specified parameters
def create_model(hidden_layers=2, activation='relu'):
    model = Sequential()
    model.add(Dense(512, activation=activation, input_shape=(784,)))
    for _ in range(hidden_layers - 1):
        model.add(Dense(512, activation=activation))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and train the model with 3 hidden layers and tanh activation
model_task3 = create_model(hidden_layers=3, activation='tanh')
history_task3 = model_task3.fit(train_images, train_labels, epochs=10, batch_size=128, 
                                validation_data=(test_images, test_labels), verbose=1)

# Plot loss and accuracy for both training and validation data
plt.plot(history_task3.history['loss'], label='Training Loss')
plt.plot(history_task3.history['val_loss'], label='Validation Loss')
plt.plot(history_task3.history['accuracy'], label='Training Accuracy')
plt.plot(history_task3.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.title('Training and Validation Metrics with 3 Hidden Layers and Tanh Activation')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 14ms/step - loss: 0.3300 - accuracy: 0.8993 - val_loss: 0.2111 - val_accuracy: 0.9363
# Epoch 2/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1258 - accuracy: 0.9612 - val_loss: 0.2951 - val_accuracy: 0.9110
# Epoch 3/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0810 - accuracy: 0.9753 - val_loss: 0.0994 - val_accuracy: 0.9682
# Epoch 4/10
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0563 - accuracy: 0.9819 - val_loss: 0.0959 - val_accuracy: 0.9710
# Epoch 5/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 0.0784 - val_accuracy: 0.9750
# Epoch 6/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0294 - accuracy: 0.9907 - val_loss: 0.0786 - val_accuracy: 0.9757
# Epoch 7/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0193 - accuracy: 0.9939 - val_loss: 0.0712 - val_accuracy: 0.9790
# Epoch 8/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0658 - val_accuracy: 0.9809
# Epoch 9/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.0761 - val_accuracy: 0.9779
# Epoch 10/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.0678 - val_accuracy: 0.9815
